# %% [markdown]
# <a href="https://colab.research.google.com/github/themanoftalent/pyt-colab/blob/master/nba_stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Nba-stats** here we do some works on nbs players teams

# %%
# importing pandas as pd 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/nba_stats"
# Out:
# nba.csv  nba-stats.ipynb

# %%
# Creating the dataframe 
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/nba_stats/nba.csv") 

# Print the dataframe 
df
# Out:
#               Name            Team  ...            College     Salary
# 0    Avery Bradley  Boston Celtics  ...              Texas  7730337.0
# 1      Jae Crowder  Boston Celtics  ...          Marquette  6796117.0
# 2     John Holland  Boston Celtics  ...  Boston University        NaN
# 3      R.J. Hunter  Boston Celtics  ...      Georgia State  1148640.0
# 4    Jonas Jerebko  Boston Celtics  ...                NaN  5000000.0
# ..             ...             ...  ...                ...        ...
# 453   Shelvin Mack       Utah Jazz  ...             Butler  2433333.0
# 454      Raul Neto       Utah Jazz  ...                NaN   900000.0
# 455   Tibor Pleiss       Utah Jazz  ...                NaN  2900000.0
# 456    Jeff Withey       Utah Jazz  ...             Kansas   947276.0
# 457            NaN             NaN  ...                NaN        NaN
#
# [458 rows x 9 columns]

# %%
df.all()
# Out:
# Name         True
# Team         True
# Number      False
# Position     True
# Age          True
# Height       True
# Weight       True
# College      True
# Salary       True
# dtype: bool

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.Salary.describe()
# Out:
# count    4.460000e+02
# mean     4.842684e+06
# std      5.229238e+06
# min      3.088800e+04
# 25%      1.044792e+06
# 50%      2.839073e+06
# 75%      6.500000e+06
# max      2.500000e+07
# Name: Salary, dtype: float64

# %%
# applying get() function 
df.get("Salary").head(10)
# Out:
# 0     7730337.0
# 1     6796117.0
# 2           NaN
# 3     1148640.0
# 4     5000000.0
# 5    12000000.0
# 6     1170960.0
# 7     2165160.0
# 8     1824360.0
# 9     3431040.0
# Name: Salary, dtype: float64

# %%
# applying get() function 
df.get("Salary").tail()
# Out:
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457          NaN
# Name: Salary, dtype: float64

# %%
df.get(["Salary", "Team", "Name"]).head(20)
# Out:
#         Salary            Team                     Name
# 0    7730337.0  Boston Celtics            Avery Bradley
# 1    6796117.0  Boston Celtics              Jae Crowder
# 2          NaN  Boston Celtics             John Holland
# 3    1148640.0  Boston Celtics              R.J. Hunter
# 4    5000000.0  Boston Celtics            Jonas Jerebko
# 5   12000000.0  Boston Celtics             Amir Johnson
# 6    1170960.0  Boston Celtics            Jordan Mickey
# 7    2165160.0  Boston Celtics             Kelly Olynyk
# 8    1824360.0  Boston Celtics             Terry Rozier
# 9    3431040.0  Boston Celtics             Marcus Smart
# 10   2569260.0  Boston Celtics          Jared Sullinger
# 11   6912869.0  Boston Celtics            Isaiah Thomas
# 12   3425510.0  Boston Celtics              Evan Turner
# 13   1749840.0  Boston Celtics              James Young
# 14   2616975.0  Boston Celtics             Tyler Zeller
# 15   3425510.0   Brooklyn Nets         Bojan Bogdanovic
# ...

# %%
df.get(["Salary", "Team", "Name"]).tail(10)
# Out:
#          Salary       Team            Name
# 448  15409570.0  Utah Jazz  Gordon Hayward
# 449   1348440.0  Utah Jazz     Rodney Hood
# 450   2050000.0  Utah Jazz      Joe Ingles
# 451    981348.0  Utah Jazz   Chris Johnson
# 452   2239800.0  Utah Jazz      Trey Lyles
# 453   2433333.0  Utah Jazz    Shelvin Mack
# 454    900000.0  Utah Jazz       Raul Neto
# 455   2900000.0  Utah Jazz    Tibor Pleiss
# 456    947276.0  Utah Jazz     Jeff Withey
# 457         NaN        NaN             NaN

# %%
df[40:50]
# Out:
#                   Name                Team  ...          College     Salary
# 40  Kristaps Porzingis     New York Knicks  ...              NaN  4131720.0
# 41      Kevin Seraphin     New York Knicks  ...              NaN  2814000.0
# 42        Lance Thomas     New York Knicks  ...             Duke  1636842.0
# 43       Sasha Vujacic     New York Knicks  ...              NaN   947276.0
# 44    Derrick Williams     New York Knicks  ...          Arizona  4000000.0
# 45         Tony Wroten     New York Knicks  ...       Washington   167406.0
# 46         Elton Brand  Philadelphia 76ers  ...             Duke        NaN
# 47       Isaiah Canaan  Philadelphia 76ers  ...     Murray State   947276.0
# 48    Robert Covington  Philadelphia 76ers  ...  Tennessee State  1000000.0
# 49         Joel Embiid  Philadelphia 76ers  ...           Kansas  4626960.0
#
# [10 rows x 9 columns]

# %%
df["Name"].head(20)
# Out:
# 0               Avery Bradley
# 1                 Jae Crowder
# 2                John Holland
# 3                 R.J. Hunter
# 4               Jonas Jerebko
# 5                Amir Johnson
# 6               Jordan Mickey
# 7                Kelly Olynyk
# 8                Terry Rozier
# 9                Marcus Smart
# 10            Jared Sullinger
# 11              Isaiah Thomas
# 12                Evan Turner
# 13                James Young
# 14               Tyler Zeller
# 15           Bojan Bogdanovic
# 16               Markel Brown
# 17            Wayne Ellington
# 18    Rondae Hollis-Jefferson
# 19               Jarrett Jack
# Name: Name, dtype: object

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.Age.plot(kind="hist")

# %%
df.Age.plot(kind="bar")

# %%
df.Salary.plot(kind="bar",facecolor="r",)

# %%
df.Salary.plot(kind="barh")

# %%
print(df.Salary.plot(kind="pie"))
# Out:
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
print(df.Age.plot(kind="pie"))
# Out:
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
print(df.Age.plot(kind="bar"))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df.Salary.plot(kind="density")

# %%
df.Salary.plot(kind="kde")

# %%
df.Salary.plot(kind="area",color="r",alpha=0.5)

# %%
df.Salary.plot(kind="line",color="y")
