# %% [markdown]
# <a href="https://colab.research.google.com/github/themanoftalent/pyt-colab/blob/master/pca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel("TrainDataFeatures.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0        lat        lon   Time  haversine_latlon_reallatlon  \
# 0           1  41.042530  29.009342  25200                     0.001068
# 1           2  41.042532  29.009343  25261                     0.003061
# 2           3  41.042537  29.009344  25322                     0.003029
# 3           4  41.042544  29.009344  25383                     0.003996
# 4           5  41.042550  29.009340  25444                     0.002881
#
#    manhatten_latlon_reallatlon  bearing_latlon_reallatlon  centroid_long  \
# 0                     0.001294                   0.001661      29.019123
# 1                     0.003677                   0.000769      29.019123
# 2                     0.004229                   0.001442      29.019123
# 3                     0.005408                   0.000619      29.016040
# 4                     0.003374                   0.000791      29.019123
#
#    centroid_lat  centroid_real_long  ...  haversine_centlatlon_centreallatlon  \
# ...

# %%
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
df.head()
# Out:
#          lat        lon   Time  haversine_latlon_reallatlon  \
# 0  41.042530  29.009342  25200                     0.001068
# 1  41.042532  29.009343  25261                     0.003061
# 2  41.042537  29.009344  25322                     0.003029
# 3  41.042544  29.009344  25383                     0.003996
# 4  41.042550  29.009340  25444                     0.002881
#
#    manhatten_latlon_reallatlon  bearing_latlon_reallatlon  centroid_long  \
# 0                     0.001294                   0.001661      29.019123
# 1                     0.003677                   0.000769      29.019123
# 2                     0.004229                   0.001442      29.019123
# 3                     0.005408                   0.000619      29.016040
# 4                     0.003374                   0.000791      29.019123
#
#    centroid_lat  centroid_real_long  centroid_real_lat  ...  \
# 0     41.045799           29.019161          41.045820  ...
# ...

# %%
df.keys()
# Out:
# Index(['lat', 'lon', 'Time', 'haversine_latlon_reallatlon',
#        'manhatten_latlon_reallatlon', 'bearing_latlon_reallatlon',
#        'centroid_long', 'centroid_lat', 'centroid_real_long',
#        'centroid_real_lat', 'haversine_latlon_centlatlon',
#        'haversine_reallatlon_centreallatlon',
#        'haversine_centlatlon_centreallatlon',
#        'haversine_latlon_centreallatlon', 'manhatten_latlon_centlatlon',
#        'manhatten_reallatlon_centreallatlon',
#        'manhatten_centlatlon_centreallatlon', 'bearing_latlon_centlatlon',
#        'bearing _reallatlon_centreallatlon',
#        'bearing _centlatlon_centreallatlon', 'speed_hvsn', 'speed_manhtn'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                                       count          mean          std  \
# lat                                  1125.0     41.045583     0.000708
# lon                                  1125.0     29.018533     0.001956
# Time                                 1125.0  39817.438222  4551.345513
# haversine_latlon_reallatlon          1125.0      0.089755     0.162089
# manhatten_latlon_reallatlon          1125.0      0.127059     0.223191
# bearing_latlon_reallatlon            1125.0      0.001243     0.001784
# centroid_long                        1125.0     29.017899     0.002180
# centroid_lat                         1125.0     41.045326     0.000839
# centroid_real_long                   1125.0     29.017363     0.003363
# centroid_real_lat                    1125.0     41.044671     0.001264
# haversine_latlon_centlatlon          1125.0      2.798612     3.746072
# haversine_reallatlon_centreallatlon  1125.0      1.422912     2.490372
# ...

# %%
df.isnull().sum()
# Out:
# lat                                    0
# lon                                    0
# Time                                   0
# haversine_latlon_reallatlon            0
# manhatten_latlon_reallatlon            0
# bearing_latlon_reallatlon              0
# centroid_long                          0
# centroid_lat                           0
# centroid_real_long                     0
# centroid_real_lat                      0
# haversine_latlon_centlatlon            0
# haversine_reallatlon_centreallatlon    0
# haversine_centlatlon_centreallatlon    0
# haversine_latlon_centreallatlon        0
# manhatten_latlon_centlatlon            0
# manhatten_reallatlon_centreallatlon    0
# manhatten_centlatlon_centreallatlon    0
# bearing_latlon_centlatlon              0
# bearing _reallatlon_centreallatlon     0
# bearing _centlatlon_centreallatlon     0
# speed_hvsn                             0
# speed_manhtn                           0
# dtype: int64

# %%
df.shape
# Out:
# (1125, 22)

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.preprocessing import StandardScaler

# %%
x = df.loc[:,].values
x = StandardScaler().fit_transform(x)

# %%
np.mean(x),np.std(x)
# Out:
# (1.3084082863173022e-13, 1.0)

# %%
feat_cols = ['ozellik'+str(i) for i in range(x.shape[1])]

# %%
normalised_df = pd.DataFrame(x,columns=feat_cols)

# %%
normalised_df.tail()
# Out:
#       ozellik0  ozellik1  ozellik2  ozellik3  ozellik4  ozellik5  ozellik6  \
# 1120 -1.144768 -1.056649  0.743311 -0.549064 -0.565581  0.275988  0.561614
# 1121 -1.176074 -1.086640  0.743311 -0.553149 -0.568812 -0.122188  0.561614
# 1122 -1.205279 -1.114613  0.743311 -0.522286 -0.538348 -0.351248 -2.283391
# 1123 -1.231402 -1.140405  0.743311 -0.526009 -0.541199  0.006664  0.561614
# 1124 -1.255937 -1.163535  0.743311 -0.531447 -0.546817 -0.001917  0.561614
#
#       ozellik7  ozellik8  ozellik9  ...  ozellik12  ozellik13  ozellik14  \
# 1120  0.564516  0.534834 -1.436979  ...  -0.562226  -0.601060  -0.526163
# 1121  0.564516 -2.043531 -1.436979  ...  -0.562226  -0.600345  -0.527477
# 1122 -2.266485  0.534834 -1.436979  ...   2.279909   0.872528   1.245606
# 1123  0.564516  0.534834 -1.436979  ...  -0.562226  -0.601044  -0.525371
# 1124  0.564516  0.534834 -0.379429  ...  -0.562226  -0.600126  -0.523329
#
#       ozellik15  ozellik16  ozellik17  ozellik18  ozellik19  ozellik20  \
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca_df = PCA(n_components=17)

# %%
principalComponents_df = pca_df.fit_transform(x)

# %%
# col_cl= ['TemelBilAn'+str(i) for i in range(x.shape[1])]
# principal_df_Df = pd.DataFrame(data = principalComponents_df
#              , columns = ['Metin 1', 'Metin 2','Metin 3', 'Metin 4',
#                           'Metin 5', 'Metin 6','Metin 7',
#                           'Metin 8','Metin 9', 
#                           'Metin 10','Metin 11', 'Metin 12','Metin 13', 'Metin 14',
#                           'Metin 15', 'Metin 16','Metin 17'])

# %%
col_cl= ['TMA_ '+str(i) for i in range(17)]

# %%
principal_df_Df = pd.DataFrame(data = principalComponents_df
             , columns =col_cl)

# %%
principal_df_Df.head()
# Out:
#      TMA_ 0    TMA_ 1    TMA_ 2    TMA_ 3    TMA_ 4    TMA_ 5    TMA_ 6  \
# 0 -2.257371  6.730758  0.660502  0.112510  0.577092 -0.110625 -1.454545
# 1 -2.182123  6.632126  0.417324  0.489539  0.482085 -0.200806 -1.948421
# 2 -2.265608  6.677259  0.651616  0.068934  0.599258 -0.126301 -1.455063
# 3  0.680808  6.925692  0.211136  0.406114 -1.046167 -0.701736 -0.959140
# 4 -2.186440  6.598216  0.428563  0.457447  0.484825 -0.197729 -1.921516
#
#      TMA_ 7    TMA_ 8    TMA_ 9   TMA_ 10   TMA_ 11   TMA_ 12   TMA_ 13  \
# 0 -1.106711  0.033386 -0.560203 -0.659128 -0.349606 -0.826769 -0.302251
# 1 -1.429481  0.149243 -0.242645 -0.599200 -0.334310 -0.830542 -0.301102
# 2 -1.206689 -0.070865 -0.625874 -0.725884 -0.361561 -0.839049 -0.300315
# 3 -2.302882  0.710169  0.173019  2.054875 -0.094539 -0.989009 -0.743776
# 4 -1.415215  0.134548 -0.269547 -0.599818 -0.336731 -0.855135 -0.299002
#
#     TMA_ 14   TMA_ 15   TMA_ 16
# 0 -0.101564  0.026395  0.026632
# 1 -0.107504 -0.005934  0.007708
# ...
